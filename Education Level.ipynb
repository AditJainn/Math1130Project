# %% [markdown]
# # Group Project (Education Level)

# %%
# %%time
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats 
from pingouin import pairwise_tests #this is for performing the pairwise tests
from pingouin import pairwise_ttests #this is for performing the pairwise tests
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime
import gzip
import json
import string
# Out:
# Wall time: 996 µs

# %% [markdown]
# ## Loading the data
#
# We plan to use the data taken from the 2020 US Census to tell us about the education levels of each state. We hypothesize that parents in highly educated states may demand that their children achieve a higher level of education, which may result in more engagement throughout online educational platforms. We got the data from data.census.gov which was collected by the U.S. Department of Commerce, and it is highly descriptive and informative.

# %%
edu_level = pd.read_csv("./Digital Learning/education_level.csv")

print(edu_level.columns)
print(edu_level.info())
edu_level.head()
# Out:
# Index(['Label (Grouping)', 'Alabama!!Total!!Estimate',
#        'Alabama!!Percent!!Estimate', 'Alabama!!Male!!Estimate',
#        'Alabama!!Percent Male!!Estimate', 'Alabama!!Female!!Estimate',
#        'Alabama!!Percent Female!!Estimate', 'Alaska!!Total!!Estimate',
#        'Alaska!!Percent!!Estimate', 'Alaska!!Male!!Estimate',
#        ...
#        'Wyoming!!Male!!Estimate', 'Wyoming!!Percent Male!!Estimate',
#        'Wyoming!!Female!!Estimate', 'Wyoming!!Percent Female!!Estimate',
#        'Puerto Rico!!Total!!Estimate', 'Puerto Rico!!Percent!!Estimate',
#        'Puerto Rico!!Male!!Estimate', 'Puerto Rico!!Percent Male!!Estimate',
#        'Puerto Rico!!Female!!Estimate',
#        'Puerto Rico!!Percent Female!!Estimate'],
#       dtype='object', length=313)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Columns: 313 entries, Label (Grouping) to Puerto Rico!!Percent Female!!Estimate
# dtypes: object(313)
# memory usage: 168.9+ KB
# None
#                                     Label (Grouping) Alabama!!Total!!Estimate  \
# 0                      AGE BY EDUCATIONAL ATTAINMENT                      NaN
# 1                          Population 18 to 24 years                  468,727
# 2                     Less than high school graduate                   62,982
# 3          High school graduate (includes equival...                  170,023
# 4                 Some college or associate's degree                  193,079
#
#   Alabama!!Percent!!Estimate Alabama!!Male!!Estimate  \
# 0                        NaN                     NaN
# 1                        (X)                 232,322
# 2                     13.40%                  35,285
# 3                     36.30%                  92,663
# 4                     41.20%                  86,872
#
#   Alabama!!Percent Male!!Estimate Alabama!!Female!!Estimate  \
# 0                             NaN                       NaN
# 1                             (X)                   236,405
# 2                          15.20%                    27,697
# 3                          39.90%                    77,360
# 4                          37.40%                   106,207
#
#   Alabama!!Percent Female!!Estimate Alaska!!Total!!Estimate  \
# 0                               NaN                     NaN
# 1                               (X)                  67,493
# 2                            11.70%                   8,915
# 3                            32.70%                  33,691
# 4                            44.90%                  22,510
#
#   Alaska!!Percent!!Estimate Alaska!!Male!!Estimate  ...  \
# 0                       NaN                    NaN  ...
# 1                       (X)                 39,428  ...
# 2                    13.20%                  6,171  ...
# 3                    49.90%                 19,837  ...
# 4                    33.40%                 12,604  ...
#
#   Wyoming!!Male!!Estimate Wyoming!!Percent Male!!Estimate  \
# 0                     NaN                             NaN
# 1                  26,623                             (X)
# 2                   3,432                          12.90%
# 3                  11,566                          43.40%
# 4                   9,270                          34.80%
#
#   Wyoming!!Female!!Estimate Wyoming!!Percent Female!!Estimate  \
# 0                       NaN                               NaN
# 1                    25,303                               (X)
# 2                     2,274                             9.00%
# 3                     7,649                            30.20%
# 4                    12,541                            49.60%
#
#   Puerto Rico!!Total!!Estimate Puerto Rico!!Percent!!Estimate  \
# 0                          NaN                            NaN
# 1                      316,387                            (X)
# 2                       22,575                          7.10%
# 3                       86,786                         27.40%
# 4                      176,214                         55.70%
#
#   Puerto Rico!!Male!!Estimate Puerto Rico!!Percent Male!!Estimate  \
# 0                         NaN                                 NaN
# 1                     159,616                                 (X)
# 2                      14,065                               8.80%
# 3                      48,471                              30.40%
# 4                      85,107                              53.30%
#
#   Puerto Rico!!Female!!Estimate Puerto Rico!!Percent Female!!Estimate
# 0                           NaN                                   NaN
# 1                       156,771                                   (X)
# 2                         8,510                                 5.40%
# 3                        38,315                                24.40%
# 4                        91,107                                58.10%
#
# [5 rows x 313 columns]

# %% [markdown]
# ## Extracting and cleaning relevant data
#
#
# The data is split up into many categories and is currently in a `wide` format with many subcategories for each state. We do not require all of that information so we will be reducing and converting it into a `narrow` format with each row corresponding to a state

# %% [markdown]
# First, I will clean the columns and rows by making them all lower case and replaceing ! with " " for the convenience of future analysis

# %%
# make column names lowercase and replace "!" with " "
edu_level.columns = [col.lower().replace("!!", " ") for col in edu_level.columns]

# make first column the index
edu_level = edu_level.set_index('label (grouping)')

# make row labels lowercase
edu_level.index = map(str.lower, edu_level.index)

edu_level
# Out:
#                                                    alabama total estimate  \
# age by educational attainment                                         NaN
#     population 18 to 24 years                                     468,727
#         less than high school graduate                             62,982
#         high school graduate (includes equivale...                170,023
#         some college or associate's degree                        193,079
# ...                                                                   ...
#         less than high school graduate                             25,395
#         high school graduate (includes equivale...                 31,997
#         some college or associate's degree                         36,662
#         bachelor's degree                                          52,385
#         graduate or professional degree                            65,470
#
#                                                    alabama percent estimate  \
# age by educational attainment                                           NaN
#     population 18 to 24 years                                           (X)
#         less than high school graduate                               13.40%
#         high school graduate (includes equivale...                   36.30%
#         some college or associate's degree                           41.20%
# ...                                                                     ...
#         less than high school graduate                                  (X)
#         high school graduate (includes equivale...                      (X)
#         some college or associate's degree                              (X)
#         bachelor's degree                                               (X)
#         graduate or professional degree                                 (X)
#
#                                                    alabama male estimate  \
# age by educational attainment                                        NaN
#     population 18 to 24 years                                    232,322
#         less than high school graduate                            35,285
#         high school graduate (includes equivale...                92,663
#         some college or associate's degree                        86,872
# ...                                                                  ...
#         less than high school graduate                            30,437
#         high school graduate (includes equivale...                40,400
#         some college or associate's degree                        48,234
#         bachelor's degree                                         69,340
#         graduate or professional degree                           87,542
#
#                                                    alabama percent male estimate  \
# age by educational attainment                                                NaN
#     population 18 to 24 years                                                (X)
#         less than high school graduate                                    15.20%
#         high school graduate (includes equivale...                        39.90%
#         some college or associate's degree                                37.40%
# ...                                                                          ...
#         less than high school graduate                                       (X)
#         high school graduate (includes equivale...                           (X)
#         some college or associate's degree                                   (X)
#         bachelor's degree                                                    (X)
#         graduate or professional degree                                      (X)
#
#                                                    alabama female estimate  \
# age by educational attainment                                          NaN
#     population 18 to 24 years                                      236,405
#         less than high school graduate                              27,697
#         high school graduate (includes equivale...                  77,360
#         some college or associate's degree                         106,207
# ...                                                                    ...
#         less than high school graduate                              19,307
#         high school graduate (includes equivale...                  24,996
#         some college or associate's degree                          30,353
#         bachelor's degree                                           42,797
#         graduate or professional degree                             56,725
#
#                                                    alabama percent female estimate  \
# age by educational attainment                                                  NaN
#     population 18 to 24 years                                                  (X)
#         less than high school graduate                                      11.70%
#         high school graduate (includes equivale...                          32.70%
#         some college or associate's degree                                  44.90%
# ...                                                                            ...
#         less than high school graduate                                         (X)
#         high school graduate (includes equivale...                             (X)
#         some college or associate's degree                                     (X)
#         bachelor's degree                                                      (X)
#         graduate or professional degree                                        (X)
#
#                                                    alaska total estimate  \
# age by educational attainment                                        NaN
#     population 18 to 24 years                                     67,493
#         less than high school graduate                             8,915
#         high school graduate (includes equivale...                33,691
#         some college or associate's degree                        22,510
# ...                                                                  ...
#         less than high school graduate                            31,565
#         high school graduate (includes equivale...                39,150
#         some college or associate's degree                        44,785
#         bachelor's degree                                         60,141
#         graduate or professional degree                           80,892
#
#                                                    alaska percent estimate  \
# age by educational attainment                                          NaN
#     population 18 to 24 years                                          (X)
#         less than high school graduate                              13.20%
#         high school graduate (includes equivale...                  49.90%
#         some college or associate's degree                          33.40%
# ...                                                                    ...
#         less than high school graduate                                 (X)
#         high school graduate (includes equivale...                     (X)
#         some college or associate's degree                             (X)
#         bachelor's degree                                              (X)
#         graduate or professional degree                                (X)
#
#                                                    alaska male estimate  \
# age by educational attainment                                       NaN
#     population 18 to 24 years                                    39,428
#         less than high school graduate                            6,171
#         high school graduate (includes equivale...               19,837
#         some college or associate's degree                       12,604
# ...                                                                 ...
#         less than high school graduate                           34,907
#         high school graduate (includes equivale...               44,846
#         some college or associate's degree                       53,253
#         bachelor's degree                                        70,386
#         graduate or professional degree                          91,175
#
#                                                    alaska percent male estimate  \
# age by educational attainment                                               NaN
#     population 18 to 24 years                                               (X)
#         less than high school graduate                                   15.70%
#         high school graduate (includes equivale...                       50.30%
#         some college or associate's degree                               32.00%
# ...                                                                         ...
#         less than high school graduate                                      (X)
#         high school graduate (includes equivale...                          (X)
#         some college or associate's degree                                  (X)
#         bachelor's degree                                                   (X)
#         graduate or professional degree                                     (X)
#
#                                                     ... wyoming male estimate  \
# age by educational attainment                       ...                   NaN
#     population 18 to 24 years                       ...                26,623
#         less than high school graduate              ...                 3,432
#         high school graduate (includes equivale...  ...                11,566
#         some college or associate's degree          ...                 9,270
# ...                                                 ...                   ...
#         less than high school graduate              ...                37,278
#         high school graduate (includes equivale...  ...                45,130
#         some college or associate's degree          ...                51,633
#         bachelor's degree                           ...                62,619
#         graduate or professional degree             ...                77,439
#
#                                                    wyoming percent male estimate  \
# age by educational attainment                                                NaN
#     population 18 to 24 years                                                (X)
#         less than high school graduate                                    12.90%
#         high school graduate (includes equivale...                        43.40%
#         some college or associate's degree                                34.80%
# ...                                                                          ...
#         less than high school graduate                                       (X)
#         high school graduate (includes equivale...                           (X)
#         some college or associate's degree                                   (X)
#         bachelor's degree                                                    (X)
#         graduate or professional degree                                      (X)
#
#                                                    wyoming female estimate  \
# age by educational attainment                                          NaN
#     population 18 to 24 years                                       25,303
#         less than high school graduate                               2,274
#         high school graduate (includes equivale...                   7,649
#         some college or associate's degree                          12,541
# ...                                                                    ...
#         less than high school graduate                              22,946
#         high school graduate (includes equivale...                  27,346
#         some college or associate's degree                          29,286
#         bachelor's degree                                           41,748
#         graduate or professional degree                             63,564
#
#                                                    wyoming percent female estimate  \
# age by educational attainment                                                  NaN
#     population 18 to 24 years                                                  (X)
#         less than high school graduate                                       9.00%
#         high school graduate (includes equivale...                          30.20%
#         some college or associate's degree                                  49.60%
# ...                                                                            ...
#         less than high school graduate                                         (X)
#         high school graduate (includes equivale...                             (X)
#         some college or associate's degree                                     (X)
#         bachelor's degree                                                      (X)
#         graduate or professional degree                                        (X)
#
#                                                    puerto rico total estimate  \
# age by educational attainment                                             NaN
#     population 18 to 24 years                                         316,387
#         less than high school graduate                                 22,575
#         high school graduate (includes equivale...                     86,786
#         some college or associate's degree                            176,214
# ...                                                                       ...
#         less than high school graduate                                 10,893
#         high school graduate (includes equivale...                     15,567
#         some college or associate's degree                             17,438
#         bachelor's degree                                              25,550
#         graduate or professional degree                                36,122
#
#                                                    puerto rico percent estimate  \
# age by educational attainment                                               NaN
#     population 18 to 24 years                                               (X)
#         less than high school graduate                                    7.10%
#         high school graduate (includes equivale...                       27.40%
#         some college or associate's degree                               55.70%
# ...                                                                         ...
#         less than high school graduate                                      (X)
#         high school graduate (includes equivale...                          (X)
#         some college or associate's degree                                  (X)
#         bachelor's degree                                                   (X)
#         graduate or professional degree                                     (X)
#
#                                                    puerto rico male estimate  \
# age by educational attainment                                            NaN
#     population 18 to 24 years                                        159,616
#         less than high school graduate                                14,065
#         high school graduate (includes equivale...                    48,471
#         some college or associate's degree                            85,107
# ...                                                                      ...
#         less than high school graduate                                12,194
#         high school graduate (includes equivale...                    16,384
#         some college or associate's degree                            19,618
#         bachelor's degree                                             30,177
#         graduate or professional degree                               46,630
#
#                                                    puerto rico percent male estimate  \
# age by educational attainment                                                    NaN
#     population 18 to 24 years                                                    (X)
#         less than high school graduate                                         8.80%
#         high school graduate (includes equivale...                            30.40%
#         some college or associate's degree                                    53.30%
# ...                                                                              ...
#         less than high school graduate                                           (X)
#         high school graduate (includes equivale...                               (X)
#         some college or associate's degree                                       (X)
#         bachelor's degree                                                        (X)
#         graduate or professional degree                                          (X)
#
#                                                    puerto rico female estimate  \
# age by educational attainment                                              NaN
#     population 18 to 24 years                                          156,771
#         less than high school graduate                                   8,510
#         high school graduate (includes equivale...                      38,315
#         some college or associate's degree                              91,107
# ...                                                                        ...
#         less than high school graduate                                   7,500
#         high school graduate (includes equivale...                      13,519
#         some college or associate's degree                              15,743
#         bachelor's degree                                               23,879
#         graduate or professional degree                                 33,169
#
#                                                    puerto rico percent female estimate
# age by educational attainment                                                      NaN
#     population 18 to 24 years                                                      (X)
#         less than high school graduate                                           5.40%
#         high school graduate (includes equivale...                              24.40%
#         some college or associate's degree                                      58.10%
# ...                                                                                ...
#         less than high school graduate                                             (X)
#         high school graduate (includes equivale...                                 (X)
#         some college or associate's degree                                         (X)
#         bachelor's degree                                                          (X)
#         graduate or professional degree                                            (X)
#
# [69 rows x 312 columns]

# %% [markdown]
# From the dataframe above it is observed that dataframe contains some <strong>NaN</strong> values as well as <strong>(X)</strong> and <strong>N</strong>
#
# <strong>NaN</strong> and <strong>(X)</strong> aren't concerns since they simply represent percentage that can not be calculated and wouldn't affect the analysis. On the other hand, <strong>N</strong> represent the lack of data that might affect the result of the analysis. However, considering that there's only a few <strong>N</strong> in the dataframe, I decided to convert both <strong>(X)</strong> and <strong>N</strong> to     <strong>NaT</strong>

# %%
# replace 'N' and '(X)' with NaN
edu_level = edu_level.replace(['N', '(X)'], pd.NaT)

edu_level.head(9)
# Out:
#                                                    alabama total estimate  \
# age by educational attainment                                         NaN
#     population 18 to 24 years                                     468,727
#         less than high school graduate                             62,982
#         high school graduate (includes equivale...                170,023
#         some college or associate's degree                        193,079
#         bachelor's degree or higher                                42,643
# college or higher                                                 235,722
#     population 25 years and over                                3,451,208
#         less than 9th grade                                       127,052
#
#                                                    alabama percent estimate  \
# age by educational attainment                                           NaN
#     population 18 to 24 years                                           NaT
#         less than high school graduate                               13.40%
#         high school graduate (includes equivale...                   36.30%
#         some college or associate's degree                           41.20%
#         bachelor's degree or higher                                   9.10%
# college or higher                                                    50.30%
#     population 25 years and over                                        NaT
#         less than 9th grade                                           3.70%
#
#                                                    alabama male estimate  \
# age by educational attainment                                        NaN
#     population 18 to 24 years                                    232,322
#         less than high school graduate                            35,285
#         high school graduate (includes equivale...                92,663
#         some college or associate's degree                        86,872
#         bachelor's degree or higher                               17,502
# college or higher                                                104,374
#     population 25 years and over                               1,643,071
#         less than 9th grade                                       68,626
#
#                                                    alabama percent male estimate  \
# age by educational attainment                                                NaN
#     population 18 to 24 years                                                NaT
#         less than high school graduate                                    15.20%
#         high school graduate (includes equivale...                        39.90%
#         some college or associate's degree                                37.40%
#         bachelor's degree or higher                                        7.50%
# college or higher                                                         44.90%
#     population 25 years and over                                             NaT
#         less than 9th grade                                                4.20%
#
#                                                    alabama female estimate  \
# age by educational attainment                                          NaN
#     population 18 to 24 years                                      236,405
#         less than high school graduate                              27,697
#         high school graduate (includes equivale...                  77,360
#         some college or associate's degree                         106,207
#         bachelor's degree or higher                                 25,141
# college or higher                                                  131,348
#     population 25 years and over                                 1,808,137
#         less than 9th grade                                         58,426
#
#                                                    alabama percent female estimate  \
# age by educational attainment                                                  NaN
#     population 18 to 24 years                                                  NaT
#         less than high school graduate                                      11.70%
#         high school graduate (includes equivale...                          32.70%
#         some college or associate's degree                                  44.90%
#         bachelor's degree or higher                                         10.60%
# college or higher                                                           55.50%
#     population 25 years and over                                               NaT
#         less than 9th grade                                                  3.20%
#
#                                                    alaska total estimate  \
# age by educational attainment                                        NaN
#     population 18 to 24 years                                     67,493
#         less than high school graduate                             8,915
#         high school graduate (includes equivale...                33,691
#         some college or associate's degree                        22,510
#         bachelor's degree or higher                                2,377
# college or higher                                                 24,887
#     population 25 years and over                                 485,779
#         less than 9th grade                                       10,548
#
#                                                    alaska percent estimate  \
# age by educational attainment                                          NaN
#     population 18 to 24 years                                          NaT
#         less than high school graduate                              13.20%
#         high school graduate (includes equivale...                  49.90%
#         some college or associate's degree                          33.40%
#         bachelor's degree or higher                                  3.50%
# college or higher                                                   36.90%
#     population 25 years and over                                       NaT
#         less than 9th grade                                          2.20%
#
#                                                    alaska male estimate  \
# age by educational attainment                                       NaN
#     population 18 to 24 years                                    39,428
#         less than high school graduate                            6,171
#         high school graduate (includes equivale...               19,837
#         some college or associate's degree                       12,604
#         bachelor's degree or higher                                 816
# college or higher                                                13,420
#     population 25 years and over                                250,710
#         less than 9th grade                                       6,519
#
#                                                    alaska percent male estimate  \
# age by educational attainment                                               NaN
#     population 18 to 24 years                                               NaT
#         less than high school graduate                                   15.70%
#         high school graduate (includes equivale...                       50.30%
#         some college or associate's degree                               32.00%
#         bachelor's degree or higher                                       2.10%
# college or higher                                                        34.10%
#     population 25 years and over                                            NaT
#         less than 9th grade                                               2.60%
#
#                                                     ... wyoming male estimate  \
# age by educational attainment                       ...                   NaN
#     population 18 to 24 years                       ...                26,623
#         less than high school graduate              ...                 3,432
#         high school graduate (includes equivale...  ...                11,566
#         some college or associate's degree          ...                 9,270
#         bachelor's degree or higher                 ...                 2,355
# college or higher                                   ...                11,625
#     population 25 years and over                    ...               201,494
#         less than 9th grade                         ...                 4,148
#
#                                                    wyoming percent male estimate  \
# age by educational attainment                                                NaN
#     population 18 to 24 years                                                NaT
#         less than high school graduate                                    12.90%
#         high school graduate (includes equivale...                        43.40%
#         some college or associate's degree                                34.80%
#         bachelor's degree or higher                                        8.80%
# college or higher                                                         43.60%
#     population 25 years and over                                             NaT
#         less than 9th grade                                                2.10%
#
#                                                    wyoming female estimate  \
# age by educational attainment                                          NaN
#     population 18 to 24 years                                       25,303
#         less than high school graduate                               2,274
#         high school graduate (includes equivale...                   7,649
#         some college or associate's degree                          12,541
#         bachelor's degree or higher                                  2,839
# college or higher                                                   15,380
#     population 25 years and over                                   193,854
#         less than 9th grade                                          3,076
#
#                                                    wyoming percent female estimate  \
# age by educational attainment                                                  NaN
#     population 18 to 24 years                                                  NaT
#         less than high school graduate                                       9.00%
#         high school graduate (includes equivale...                          30.20%
#         some college or associate's degree                                  49.60%
#         bachelor's degree or higher                                         11.20%
# college or higher                                                           60.80%
#     population 25 years and over                                               NaT
#         less than 9th grade                                                  1.60%
#
#                                                    puerto rico total estimate  \
# age by educational attainment                                             NaN
#     population 18 to 24 years                                         316,387
#         less than high school graduate                                 22,575
#         high school graduate (includes equivale...                     86,786
#         some college or associate's degree                            176,214
#         bachelor's degree or higher                                    30,812
# college or higher                                                     207,026
#     population 25 years and over                                    2,401,409
#         less than 9th grade                                           309,413
#
#                                                    puerto rico percent estimate  \
# age by educational attainment                                               NaN
#     population 18 to 24 years                                               NaT
#         less than high school graduate                                    7.10%
#         high school graduate (includes equivale...                       27.40%
#         some college or associate's degree                               55.70%
#         bachelor's degree or higher                                       9.70%
# college or higher                                                        65.40%
#     population 25 years and over                                            NaT
#         less than 9th grade                                              12.90%
#
#                                                    puerto rico male estimate  \
# age by educational attainment                                            NaN
#     population 18 to 24 years                                        159,616
#         less than high school graduate                                14,065
#         high school graduate (includes equivale...                    48,471
#         some college or associate's degree                            85,107
#         bachelor's degree or higher                                   11,973
# college or higher                                                     97,080
#     population 25 years and over                                   1,107,798
#         less than 9th grade                                          153,282
#
#                                                    puerto rico percent male estimate  \
# age by educational attainment                                                    NaN
#     population 18 to 24 years                                                    NaT
#         less than high school graduate                                         8.80%
#         high school graduate (includes equivale...                            30.40%
#         some college or associate's degree                                    53.30%
#         bachelor's degree or higher                                            7.50%
# college or higher                                                             60.80%
#     population 25 years and over                                                 NaT
#         less than 9th grade                                                   13.80%
#
#                                                    puerto rico female estimate  \
# age by educational attainment                                              NaN
#     population 18 to 24 years                                          156,771
#         less than high school graduate                                   8,510
#         high school graduate (includes equivale...                      38,315
#         some college or associate's degree                              91,107
#         bachelor's degree or higher                                     18,839
# college or higher                                                      109,946
#     population 25 years and over                                     1,293,611
#         less than 9th grade                                            156,131
#
#                                                    puerto rico percent female estimate
# age by educational attainment                                                      NaN
#     population 18 to 24 years                                                      NaT
#         less than high school graduate                                           5.40%
#         high school graduate (includes equivale...                              24.40%
#         some college or associate's degree                                      58.10%
#         bachelor's degree or higher                                             12.00%
# college or higher                                                               70.10%
#     population 25 years and over                                                   NaT
#         less than 9th grade                                                     12.10%
#
# [9 rows x 312 columns]

# %% [markdown]
# For the convenience and the interest of time, Excel was used to create a new row naemd "college or higher" which includes number and percentage of population between 18 to 24 who achived education level higher than college. This new row will be used for finding out education level of each state

# %%
# make a new date set that only incuded row "college or higher" and column ends with percent estimante
edu_level_college_or_higher = edu_level.iloc[6]

edu_level_college_or_higher = edu_level_college_or_higher.filter(like='percent estimate')

edu_level_college_or_higher = edu_level_college_or_higher.T.to_frame()

# drop "percent estimate" from the index so that it only incudese name of state
new_index = [label.split("percent estimate")[0].strip() for label in edu_level_college_or_higher.index]
edu_level_college_or_higher = edu_level_college_or_higher.rename(index=dict(zip(edu_level_college_or_higher.index, new_index)))

edu_level_college_or_higher
# Out:
#                      college or higher
# alabama                         50.30%
# alaska                          36.90%
# arizona                         49.40%
# arkansas                        48.50%
# california                      56.30%
# colorado                        52.50%
# connecticut                     60.20%
# delaware                        51.40%
# district of columbia            71.40%
# florida                         52.80%
# georgia                         48.30%
# hawaii                          50.20%
# idaho                           45.90%
# illinois                        56.90%
# indiana                         50.00%
# iowa                            58.40%
# kansas                          56.30%
# kentucky                        50.90%
# louisiana                       46.70%
# maine                           51.90%
# maryland                        56.20%
# massachusetts                   60.00%
# michigan                        53.90%
# minnesota                       57.10%
# mississippi                     51.90%
# missouri                        54.70%
# montana                         49.60%
# nebraska                        58.50%
# nevada                          43.40%
# new hampshire                   57.30%
# new jersey                      59.70%
# new mexico                      43.90%
# new york                        60.70%
# north carolina                  55.00%
# north dakota                    62.00%
# ohio                            50.90%
# oklahoma                        44.80%
# oregon                          51.20%
# pennsylvania                    51.70%
# rhode island                    57.20%
# south carolina                  51.80%
# south dakota                    52.50%
# tennessee                       50.70%
# texas                           49.50%
# utah                            53.70%
# vermont                         60.10%
# virginia                        55.80%
# washington                      52.40%
# west virginia                   45.70%
# wisconsin                       53.50%
# wyoming                         52.00%
# puerto rico                     65.40%

# %%
# split the strings in the index on "percent estimate" and keep only the first part
new_index = [label.split("percent estimate")[0].strip() for label in edu_level_college_or_higher.index]

# create a new DataFrame with updated index and columns
edu_level_college_or_higher = edu_level_college_or_higher.rename(index=dict(zip(edu_level_college_or_higher.index, new_index)))

# name the first column state
edu_level_college_or_higher = edu_level_college_or_higher.reset_index().rename(columns={'index': 'state'})


edu_level_college_or_higher
# Out:
#                    state college or higher
# 0                alabama            50.30%
# 1                 alaska            36.90%
# 2                arizona            49.40%
# 3               arkansas            48.50%
# 4             california            56.30%
# 5               colorado            52.50%
# 6            connecticut            60.20%
# 7               delaware            51.40%
# 8   district of columbia            71.40%
# 9                florida            52.80%
# 10               georgia            48.30%
# 11                hawaii            50.20%
# 12                 idaho            45.90%
# 13              illinois            56.90%
# 14               indiana            50.00%
# 15                  iowa            58.40%
# 16                kansas            56.30%
# 17              kentucky            50.90%
# 18             louisiana            46.70%
# 19                 maine            51.90%
# 20              maryland            56.20%
# 21         massachusetts            60.00%
# 22              michigan            53.90%
# 23             minnesota            57.10%
# 24           mississippi            51.90%
# 25              missouri            54.70%
# 26               montana            49.60%
# 27              nebraska            58.50%
# 28                nevada            43.40%
# 29         new hampshire            57.30%
# 30            new jersey            59.70%
# 31            new mexico            43.90%
# 32              new york            60.70%
# 33        north carolina            55.00%
# 34          north dakota            62.00%
# 35                  ohio            50.90%
# 36              oklahoma            44.80%
# 37                oregon            51.20%
# 38          pennsylvania            51.70%
# 39          rhode island            57.20%
# 40        south carolina            51.80%
# 41          south dakota            52.50%
# 42             tennessee            50.70%
# 43                 texas            49.50%
# 44                  utah            53.70%
# 45               vermont            60.10%
# 46              virginia            55.80%
# 47            washington            52.40%
# 48         west virginia            45.70%
# 49             wisconsin            53.50%
# 50               wyoming            52.00%
# 51           puerto rico            65.40%

# %% [markdown]
# Now, I'm going to take a look at engagement_data, which was given from the case, to find out students' engagement level. First, I will add a new column which contains district_id for future analysis which will calculate education level for each district(state) for seperate csv files in engagement_data folder.

# %%
# Adding district_id column to csv files in engagement data folder

# Path to the engagement_data folder
folder_path = 'Digital Learning/engagement_data'

# Loop through each file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(folder_path, filename)
        
        # Read the CSV file into a dataframe
        df = pd.read_csv(file_path)
        
        # Extract the district ID from the filename
        district_id = filename.split('.')[0]
        
        # Add a new column to the dataframe with the district ID
        df['district_id'] = district_id
        
        # Write the modified dataframe back to the CSV file
        df.to_csv(file_path, index=False)

# %% [markdown]
# Also, since engagement data is bunch of csv files in a folder, I'm going to append all the csv files into one dataframe for the convenience of the future analysis and calculation.

# %%
# Combine all engagement data to one dataframe

# Set the directory path to the folder containing the CSV files
directory = 'Digital Learning/engagement_data'

# Initialize an empty list to hold the DataFrames
df_list = []

# Loop through each CSV file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        # Read the CSV file into a DataFrame
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        
        # Append the DataFrame to the list
        df_list.append(df)

# Concatenate all the DataFrames in the list into a single DataFrame
engagement_data = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# Finally, I will calculate engagement index per state by using district_info dataframe. I used district_id column to find out the state.

# %%
# Get engagement by state
# Load district information data
district_info = pd.read_csv('./Digital Learning/districts_info.csv')

# Merge engagement and district information data
merged_data = pd.merge(engagement_data, district_info, on='district_id')

# Calculate average engagement level per state
avg_engagement = merged_data.groupby('state')['engagement_index'].mean().reset_index()

# Create new data frame with state and engagement_index columns
engagement_by_state = avg_engagement[['state', 'engagement_index']]

# make state names lower case 
engagement_by_state['state'] = engagement_by_state['state'].str.lower()

engagement_by_state
# Out:
#                    state  engagement_index
# 0                arizona        740.788101
# 1             california        113.330664
# 2            connecticut        257.456419
# 3   district of columbia        261.397662
# 4                florida         64.088064
# 5               illinois        200.544588
# 6                indiana        221.990979
# 7          massachusetts        217.493218
# 8               michigan        104.451529
# 9              minnesota        160.833411
# 10              missouri         88.400098
# 11         new hampshire        328.008548
# 12            new jersey        151.081847
# 13              new york        530.183330
# 14        north carolina         76.842376
# 15          north dakota        423.002601
# 16                  ohio        148.917549
# 17             tennessee         72.697953
# 18                 texas         73.514148
# 19                  utah        119.971871
# 20              virginia         98.533299
# 21            washington         76.234729
# 22             wisconsin        246.439945

# %% [markdown]
# After calculating engagement index, it became clear thet further cleaning is reuired for engagement data as meaningful insight couldn't be be extracted. Also, it shows some critical flaws as engagement index of Arinona is 740 while Washington and texas is only around 75. This indicatese that there could be possible outliers in the enagagement data. Therefore, I decided to take a look at product_info dataframe to see if there's certain product types that contain a lot of outliers.

# %%
# Load products_info CSV

product_info = pd.read_csv("./Digital Learning/products_info.csv")

# rename the column
product_info = product_info.rename(columns={"LP ID": "lp_id"})

# make other columns lower case
product_info.columns = product_info.columns.str.lower()

# Merge engagement and district information data
engagement_by_product = pd.merge(engagement_data, product_info, on='lp_id')

# %%
product_info["primary essential function"].unique()
# Out:
# array(['LC - Digital Learning Platforms',
#        'LC - Sites, Resources & Reference - Games & Simulations',
#        'LC - Courseware & Textbooks', 'LC - Study Tools - Q&A',
#        'LC - Sites, Resources & Reference - Streaming Services',
#        'LC - Study Tools',
#        'CM - Teacher Resources - Professional Learning',
#        'SDO - Learning Management Systems (LMS)',
#        'LC - Content Creation & Curation',
#        'LC - Sites, Resources & Reference',
#        'LC - Online Course Providers & Technical Skills Development',
#        'CM - Classroom Engagement & Instruction - Communication & Messaging',
#        'SDO - School Management Software - SSO',
#        'LC - Sites, Resources & Reference - Thesaurus & Dictionary',
#        'LC/CM/SDO - Other', 'SDO - Data, Analytics & Reporting',
#        'LC - Sites, Resources & Reference - Encyclopedia',
#        'CM - Classroom Engagement & Instruction - Classroom Management',
#        'LC - Sites, Resources & Reference - Digital Collection & Repository',
#        'CM - Classroom Engagement & Instruction - Assessment & Classroom Response',
#        'CM - Virtual Classroom - Video Conferencing & Screen Sharing',
#        'SDO - Data, Analytics & Reporting - Site Hosting & Data Warehousing',
#        nan,
#        'SDO - Data, Analytics & Reporting - Student Information Systems (SIS)',
#        'LC - Career Planning & Job Search', 'SDO - Human Resources',
#        'SDO - School Management Software - Mobile Device Management',
#        'CM - Teacher Resources - Grading & Attendance',
#        'LC - Study Tools - Tutoring',
#        'SDO - Large-Scale & Standardized Testing',
#        'CM - Teacher Resources - Lesson Planning',
#        'LC - Sites, Resources & References - Learning Materials & Supplies',
#        'SDO - Admissions, Enrollment & Rostering',
#        'LC - Study Tools - Test Prep & Study Skills',
#        'SDO - Environmental, Health & Safety (EHS) Compliance',
#        'SDO - Other'], dtype=object)

# %% [markdown]
# After takinga look at product types(primary essential function) I decided to only include LC = Learning & Curriculum since CM = Classroom Management, and SDO = School & District Operations are not directly related to students' engagement in school.

# %%
selected_values = ['LC - Digital Learning Platforms',
                   'LC - Courseware & Textbooks',
                   'LC - Study Tools - Q&A',
                   'LC - Sites, Resources & Reference - Streaming Services',
                   'LC - Study Tools',
                   'LC - Content Creation & Curation',
                   'LC - Sites, Resources & Reference',
                   'LC - Online Course Providers & Technical Skills Development',
                   'LC - Sites, Resources & Reference - Thesaurus & Dictionary',
                   'LC - Sites, Resources & Reference - Encyclopedia',
                   'LC - Sites, Resources & Reference - Digital Collection & Repository',
                   'LC - Career Planning & Job Search',
                   'LC - Study Tools - Tutoring',
                   'LC - Sites, Resources & References - Learning Materials & Supplies',
                   'LC - Study Tools - Test Prep & Study Skills']

engagement_by_product_filtered = engagement_by_product[engagement_by_product['primary essential function'].isin(selected_values)]

# %% [markdown]
# Now, I will further investigate the dataframe to see if there some products types within LC that contain large number of outliers.

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.boxplot(x="primary essential function", y="engagement_index", data=engagement_by_product_filtered)
ax.set_title("Engagement Index per Primary Essential Function", fontsize=16)
ax.set_xlabel("Primary Essential Function", fontsize=14)
ax.set_ylabel("Engagement Index", fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# From the box plot above it became clear that "LC - Content Creation & Curation" and "LC - Online Course Providers & Technical Skills Development" contains significant number of outliers. Therefore, I decided to exclute those two primary essentail funcion when calculating engagement index per state.

# %%
engagement_by_product_filtered = engagement_by_product_filtered[~engagement_by_product_filtered['primary essential function'].isin(['LC - Content Creation & Curation', 'LC - Online Course Providers & Technical Skills Development'])]

# %%
# Merge engagement and district information data
merged_data = pd.merge(engagement_by_product_filtered, district_info, on='district_id')

# Calculate average engagement level per state
avg_engagement = merged_data.groupby('state')['engagement_index'].mean().reset_index()

# Create new data frame with state and engagement_index columns
engagement_by_state = avg_engagement[['state', 'engagement_index']]
engagement_by_state['state'] = engagement_by_state['state'].str.lower()

engagement_by_state
# Out:
#                    state  engagement_index
# 0                arizona        341.164569
# 1             california         84.155646
# 2            connecticut        113.396817
# 3   district of columbia        187.521577
# 4                florida         68.169898
# 5               illinois        122.507214
# 6                indiana        160.468886
# 7          massachusetts        103.192857
# 8               michigan         83.514291
# 9              minnesota         84.663493
# 10              missouri         72.354992
# 11         new hampshire        109.120690
# 12            new jersey         92.548404
# 13              new york        202.038478
# 14        north carolina         59.971059
# 15          north dakota        341.956852
# 16                  ohio        102.250697
# 17             tennessee         73.262832
# 18                 texas         68.733725
# 19                  utah        106.624033
# 20              virginia         86.407409
# 21            washington         64.335744
# 22             wisconsin        104.567391

# %% [markdown]
# Now that I have education level and engagement level by state, I'm going to investigate if there's any relationship between two variables.

# %%
edu_level_engagement_by_state = pd.merge(engagement_by_state, edu_level_college_or_higher, on='state', how='inner')

edu_level_engagement_by_state
# Out:
#                    state  engagement_index college or higher
# 0                arizona        341.164569            49.40%
# 1             california         84.155646            56.30%
# 2            connecticut        113.396817            60.20%
# 3   district of columbia        187.521577            71.40%
# 4                florida         68.169898            52.80%
# 5               illinois        122.507214            56.90%
# 6                indiana        160.468886            50.00%
# 7          massachusetts        103.192857            60.00%
# 8               michigan         83.514291            53.90%
# 9              minnesota         84.663493            57.10%
# 10              missouri         72.354992            54.70%
# 11         new hampshire        109.120690            57.30%
# 12            new jersey         92.548404            59.70%
# 13              new york        202.038478            60.70%
# 14        north carolina         59.971059            55.00%
# 15          north dakota        341.956852            62.00%
# 16                  ohio        102.250697            50.90%
# 17             tennessee         73.262832            50.70%
# 18                 texas         68.733725            49.50%
# 19                  utah        106.624033            53.70%
# 20              virginia         86.407409            55.80%
# 21            washington         64.335744            52.40%
# 22             wisconsin        104.567391            53.50%

# %%
# Get the data
x = edu_level_engagement_by_state['college or higher']
y = edu_level_engagement_by_state['engagement_index']

# Create a scatter plot
plt.scatter(x=x, y=y)

# Add axis labels and a title
plt.xlabel('Education Level')
plt.ylabel('Engagement Index')
plt.title('Engagement Index vs Education Level')


plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# From the following scatter plot no sepecific pattern could be observed, so I decided to run regression and correlation test to see if there's any relationship between Engagement Index and Education Level

# %%
edu_level_engagement_by_state['college or higher'] = edu_level_engagement_by_state['college or higher'].apply(lambda x: float(x.strip('%'))/100)

# %%
x = edu_level_engagement_by_state['college or higher']
y = edu_level_engagement_by_state['engagement_index']

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Print the regression results
print("Slope:", slope)
print("Intercept:", intercept)
print("R-squared:", r_value**2)
print("p-value:", p_value)
print("Standard error:", std_err)

# Calculate correlation
corr = np.corrcoef(x, y)[0,1]
print("Correlation:", corr)

# Create scatter plot
plt.scatter(x, y)

# Create x values for regression line
x_reg = np.linspace(min(x), max(x), 100)

# Calculate y values for regression line
y_reg = slope * x_reg + intercept

# Add regression line to plot
plt.plot(x_reg, y_reg, color='red')

# Add title and labels
plt.title('Regression line for engagement and education')
plt.xlabel('Education Level')
plt.ylabel('Engagement Level')

# Show plot
plt.show()
# Out:
# Slope: 376.6105257913757
# Intercept: -87.05978197237538
# R-squared: 0.059516343916506974
# p-value: 0.2619482876749548
# Standard error: 326.69336217080127
# Correlation: 0.24395971781527168

# %% [markdown]
# The linear regression model for the data shows a positive slope of 376.61. This means that the engagement index tends to increase as the percentage of college education in a state increases.
#
# The R-squared value of 0.059 indicates that only 5.9% of the variation in the engagement index can be explained by the variation in college education.
#
# The p-value of 0.261 which is far greater than 0.05, meaning that there is not strong evidence to reject the null hypothesis. Therefore, there is no strong relationship between college education and engagement index.
#
# The standard error of the slope estimate is 326.69, which indicates the variability of the slope estimate across different samples.
#
# The correlation coefficient of 0.243 suggests that there is a weak positive correlation between college education and engagement index. This means that there is a tendency for higher levels of college education to be associated with higher levels of engagement, but the relationship is not very strong.

# %% [markdown]
# Overall, the analysis suggests that there is a weak positive relationship between college education and engagement index. However, the relationship is not strong enough to conclude that there is a causal relationship between the two variables. The low R-squared value and non-significant p-value indicate that there may be other factors besides college education that influence engagement index. Additionally, the wide standard error suggests that there is a fair amount of uncertainty in the slope estimate. Nonetheless, the positive slope coefficient indicates that college education may be one of several factors that contribute to higher levels of engagement index.
